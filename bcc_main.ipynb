# %% [markdown]
# # <span style="color: #ff058f;"> **🎗 Breast Cancer Classfication**</span>

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Project Domain: 🩺 Health Care__
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ![resized_image.jpg](attachment:resized_image.jpg)
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __Problem Statement:__
# The problem statement for breast cancer classification typically revolves around the need for accurate and efficient diagnosis of breast cancer from medical imaging data, such as mammograms. The goal is to develop machine learning models that can effectively distinguish between benign and malignant breast tumors based on features extracted from these images.
#
# #### __Goal:__
# The goal is to build a robust classification model that minimizes false positives and false negatives, enabling timely and accurate diagnosis of breast cancer, thereby improving patient outcomes and healthcare efficiency.
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ### **0.1 Load Dataset:**

# %%
#Importing dependencies
import pandas as pd

# %%
#Loading the training  dataset in pandas dataframe
df=pd.read_csv('data.csv')
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
#-------------------------------------------------------------
#Shape
print("Shape of the dataset :",df.shape)
#-------------------------------------------------------------
df.head(5)
# Out:
# Shape of the dataset : (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### **0.2 Column Description:**

# %% [markdown]
# | Column Name             | Description                                                   |
# |-------------------------|---------------------------------------------------------------|
# | id                      | Unique identifier for each observation                        |
# | diagnosis               | Categorical variable indicating the diagnosis of the tumor (M-Malignant or B-Benign) |
# | radius_mean             | Mean radius of the tumor                                      |
# | texture_mean            | Mean texture value of the tumor                               |
# | perimeter_mean          | Mean perimeter of the tumor                                   |
# | area_mean               | Mean area of the tumor                                        |
# | smoothness_mean         | Mean smoothness value of the tumor                            |
# | compactness_mean        | Mean compactness value of the tumor                           |
# | concavity_mean          | Mean concavity value of the tumor                             |
# | concave points_mean     | Mean number of concave portions of the contour                |
# | symmetry_mean           | Mean symmetry value of the tumor                              |
# | fractal_dimension_mean  | Mean fractal dimension value of the tumor                     |
# | radius_se               | Standard error of the radius of the tumor                     |
# | texture_se              | Standard error of the texture value of the tumor              |
# | perimeter_se            | Standard error of the perimeter of the tumor                  |
# | area_se                 | Standard error of the area of the tumor                       |
# | smoothness_se           | Standard error of the smoothness value of the tumor           |
# | compactness_se          | Standard error of the compactness value of the tumor          |
# | concavity_se            | Standard error of the concavity value of the tumor            |
# | concave points_se       | Standard error of the number of concave portions of the contour |
# | symmetry_se             | Standard error of the symmetry value of the tumor             |
# | fractal_dimension_se    | Standard error of the fractal dimension value of the tumor    |
# | radius_worst            | Worst (largest) radius of the tumor                           |
# | texture_worst           | Worst (largest) texture value of the tumor                    |
# | perimeter_worst         | Worst (largest) perimeter of the tumor                        |
# | area_worst              | Worst (largest) area of the tumor                             |
# | smoothness_worst        | Worst (largest) smoothness value of the tumor                 |
# | compactness_worst       | Worst (largest) compactness value of the tumor                |
# | concavity_worst         | Worst (largest) concavity value of the tumor                  |
# | concave points_worst    | Worst (largest) number of concave portions of the contour     |
# | symmetry_worst          | Worst (largest) symmetry value of the tumor                   |
# | fractal_dimension_worst | Worst (largest) fractal dimension value of the tumor          |

# %% [markdown]
# #### __0.3 Checking for Data Quality:__

# %%
#Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# __0.3.1 Checking for Duplicates and Null Values:__

# %%
#Checking for duplicates
print("1. Duplicated Rows :",df.duplicated().sum())
#--------------------------------------------------------------------
#Checking for NaN values
print("2. Null Values :")
pd.DataFrame(df.isna().sum()).transpose()
# Out:
# 1. Duplicated Rows : 0
# 2. Null Values :
#    id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   0          0            0             0               0          0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0                0                 0               0                    0
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0              0                       0          0           0             0
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0        0              0               0             0                  0
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0            0                     0             0              0
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0                0           0                 0                  0
#
# ...

# %% [markdown]
#  __0.3.2 Checking for Errors and Unique Value Counts in Categorical Columns:__

# %%
#Categorical columns
categorical_columns = ["diagnosis"]
#--------------------------------------------------------------------------------------------
for column in categorical_columns:
    print(f'Unique Value Counts for "{column}":')
    print(df[column].value_counts().to_dict())
# Out:
# Unique Value Counts for "diagnosis":
# {'B': 357, 'M': 212}

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#   __Data Quality Assessment :__
# - The dataset is free from duplicates. However, it contains a column named "Unnamed: 32," which consists of only null values in all rows. Apart from the "Unnamed: 32" column, all other columns are free from null values.
#
# - The column data types are appropriately relevant.
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # __Step 1: Exploratory Data Analysis (EDA)__

# %%
#Importing Dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### __1.1 Removing unnecessary columns:__
# - Removing the column "id" and "Unnamed: 32".

# %%
df=df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'diagnosis']]
print("Shape of the dataframe after removing the unnecessary columns:",df.shape)
# Out:
# Shape of the dataframe after removing the unnecessary columns: (569, 31)

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# - __Feature Variables:__
#    - 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'
#
# - __Target Variable:__
#    - 'diagnosis'
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
#  #### __1.2 Summary Statistics:__

# %%
numerical_columns =['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
#-------------------------------------------------------------------------------------------------------------------
print("Summary Statistics :")
df[numerical_columns].describe()
# Out:
# Summary Statistics :
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# ...

# %% [markdown]
# #### __1.3. Distribution of Numerical Variables:__

# %%
#Histplot
plt.figure(figsize=(20, 20))
for i, col in enumerate(numerical_columns):
    plt.subplot(6, 5, i+1)
    sns.histplot(df[col],kde=True,color="red")
    plt.title(f'Distribution of {col}')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
#
# - Columns such as **'radius_mean','texture_mean', 'perimeter_mean','smoothness_mean','symmetry_mean','texture_worst','smoothness_worst','concave points_worst','symmetry_worst','concave points_se' and 'radius_worst'** are likely to follow a normal distribution.
#
# - The remaining columns follow a combination of highly right-skewed and moderately right-skewed distributions.
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __1.4 Frequency Distribution of Categories in Each Categorical Column :__

# %%
#Pie chart
plt.figure(figsize=(12,3))
violet_colors = ["green","red"]
#------------------------------------------------------------------------------------------------
outcome_counts = df['diagnosis'].value_counts()
labels = outcome_counts.index.tolist()
counts = outcome_counts.values.tolist()
explode = [0.03] * len(counts) 
plt.pie(counts, labels=labels, autopct=lambda p: '{:.0f}\n({:.1f}%)'.format(p * sum(counts) / 100, p), startangle=90, explode=explode, colors=violet_colors,textprops={'fontsize': 12}, wedgeprops={'linewidth': 2, 'edgecolor': 'white'})
plt.axis('equal')  
plt.title('Frequency Distribution of Categories in "diagnosis"',fontsize=12) 
#------------------------------------------------------------------------------------------------
plt.tight_layout()
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - The "diagnosis" column exhibits an imbalanced distribution, with M (Malignant) data comprising 37.3% of the dataset, while B (Benign) data represents the majority at 62.7%.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __1.5 Distribution of Diagnosis in Continuous Columns:__

# %%
#----------------------------------------------------------------------------------------------
#Standardization for visualizing purpose only
df_standardized = (df[numerical_columns] - df[numerical_columns].mean()) / (df[numerical_columns].std())  
#----------------------------------------------------------------------------------------------
#Concatenating the continuous standardized variables with categorized target varibale
df_new = pd.concat([df["diagnosis"], df_standardized], axis=1)
#----------------------------------------------------------------------------------------------
#Melting the data frame for our convinience
df_melted = pd.melt(df_new, id_vars="diagnosis",var_name="numerical_features",value_name='value')
#----------------------------------------------------------------------------------------------
#Swarmplot
custom_palette = {"M": "red", "B": "green"} 
plt.figure(figsize=(22, 10))
sns.swarmplot(x="numerical_features", y="value", hue="diagnosis", data=df_melted, palette=custom_palette)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - The features 'radius_mean' and 'area_se' shows a tendency towards partial separation between malignant and benign cases, suggesting they may have some discriminatory potential. However, the distinction is not entirely clear-cut,indicating that further analysis may be needed to fully assess their effectiveness in classifying tumor types.
# - When examining 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', and 'texture_mean' on the same plot, the distribution of malignant and benign cases appears more intertwined. These features display a less clear separation between the two classes, suggesting that they may not provide as much discriminatory information for distinguishing between malignant and benign tumors.
# - The features 'radius_worst' and 'area_worst' exhibit a noticeable trend they seem to predominantly separate malignant and benign cases, although there might be some overlap. Conversely, when considering features like 'compactness_se', 'symmetry_se', and 'smoothness_worst', the swarm plot suggests a more mixed distribution between malignant and benign cases. This mixing makes it challenging to reliably classify cases based solely on these features.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __1.6 Correlation Matrix :__
# - Using Pearson Correlation

# %%
#df[numerical_columns].corr().style.background_gradient()
#Heat map
plt.figure(figsize=(20, 20))
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='Reds', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - Observing the graph, it's evident that there is significant collinearity or multicollinearity among all the numerical variables.
# -  'radius_mean', 'perimeter_mean', and 'area_mean' exhibit high correlation with each other, indicating redundancy in using all three features.
# - The features 'compactness_mean', 'concavity_mean', and 'concave points_mean' exhibit correlation with each other. Similarly, 'radius_se', 'perimeter_se', and 'area_se' demonstrate correlation, as do 'radius_worst', 'perimeter_worst', and 'area_worst'.
# - The features 'compactness_worst', 'concavity_worst', and 'concave points_worst' display correlation, suggesting the selection of only one of these features for analysis. Likewise, 'compactness_se', 'concavity_se', and 'concave points_se' demonstrate correlation, indicating the necessity of using only one of these features.
# - Furthermore, there is a correlation between 'texture_mean' and 'texture_worst', necessitating the selection of one of them for further analysis. Lastly, the correlation observed between 'area_worst' and 'area_mean' suggests that only one of these features should be utilized to avoid redundancy in the analysis.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __1.7 Checking for Outliers:__

# %%
#Boxplot
plt.figure(figsize=(22, 50))
for i, col in enumerate(numerical_columns):
    plt.subplot(15,2, i+1)
    sns.boxplot(df[col], color='green')
    plt.title(f'Distribution of {col}')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - The presence of outliers is evident across all variables in the dataset.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # __Step 2: Machine Learning__

# %% [markdown]
# #### __2.1 Feature Selection:__
# - Choosing the most relevant numerical features involves setting a threshold value of 0.7 to select the optimal ones.

# %%
def correlation(dataset,threshold):
    correlation_columns=set()
    correlation_matrix=dataset.corr()
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i,j])>threshold:
                 column_name=correlation_matrix.columns[i]
                 correlation_columns.add(column_name)
    return correlation_columns
#--------------------------------------------------------------------------------
c=correlation(df[numerical_columns],0.7)
#--------------------------------------------------------------------------------
#Creating a new dataframe
df_new=df.drop(c,axis=1)
#--------------------------------------------------------------------------------
print("Shape of the dataset after removing redundancies",df_new.shape)
df_new.head(3)
# Out:
# Shape of the dataset after removing redundancies (569, 11)
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
#
#    symmetry_mean  fractal_dimension_mean  texture_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053       0.006399
# 1         0.1812                 0.05667      0.7339       0.005225
# 2         0.2069                 0.05999      0.7869       0.006150
#
#    symmetry_se  symmetry_worst diagnosis
# 0      0.03003          0.4601         M
# 1      0.01389          0.2750         M
# 2      0.02250          0.3613         M

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - Among the 30 feature variables, 10 were selected based on their correlation.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __2.2 Normalizing the Outliers:__

# %%
#Histplot
plt.figure(figsize=(20, 20))
for i, col in enumerate(['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se', 'symmetry_se', 'symmetry_worst']):
    plt.subplot(5, 2, i+1)
    sns.histplot(df[col],kde=True,color="green")
    plt.title(f'Distribution of {col}')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations:__
# - Certain selected numerical features exhibit minimal outliers, let's proceed with constructing the model and evaluating its performance.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### __2.3 Model Training and Evaluation:__

# %%
#Importing dependencies
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,f1_score

# %% [markdown]
# __2.3.1 Selecting Feature Variables and Target Variable:__

# %%
#Feature Variables (X)
selected_features=['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se', 'symmetry_se', 'symmetry_worst']
X=df_new[selected_features]
#-----------------------------------------------------------------------
#Target Variable (y)
y=df_new["diagnosis"]
#-----------------------------------------------------------------------
print("Shape of X :",X.shape)
print("Shape of y :",y.shape)
# Out:
# Shape of X : (569, 10)
# Shape of y : (569,)

# %% [markdown]
# __2.3.2 Encoding the Categorical Column:__

# %%
#Encoding the target variable manually
y_encoded=y.replace({"M":1,"B":0})

# %% [markdown]
# __2.3.3 Train Test Split and Scaling:__

# %%
# Split the datasets for training and testing 
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, stratify=y,random_state=7) 
#------------------------------------------------------------------------------------------------------------------
#Scaling the data using Standard Scaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %% [markdown]
# __2.3.4 Model selection and Training:__

# %% [markdown]
# Different classification models,such as
#
# 1. `Logistic Regression`
#
# 2. `Decision Tree Classifier`_
#
# 3. `Random Forest Classifier`_
#
# 4. `CatBoost Classifier`
#
# 5. `XGBoost Classifier`
#
# 6. `Support Vector Classifier`
#
# 7. `K Nearest Neighbors Class`
#
# are trained and checked for performance.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
models = {
            #"Logistic Regression": LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=100),
            "Logistic Regression": LogisticRegression(multi_class='auto'),
            "Decision Tree": DecisionTreeClassifier(random_state=7),
            "Random Forest": RandomForestClassifier(random_state=7),
            "CatBoost": CatBoostClassifier(random_state=7),
            "XGBoost": XGBClassifier(),
            "SVC": SVC(),
            "KNN": KNeighborsClassifier(n_neighbors=5)
         }
#------------------------------------------------------------------------------------------
metrics = []
#------------------------------------------------------------------------------------------
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred, average='weighted')
    metrics.append({'Model': name, 'Train Accuracy': train_acc, 'Test Accuracy': test_acc, 'F1 Score': f1})
#------------------------------------------------------------------------------------------
metrics_df = pd.DataFrame(metrics)

# %%
metrics_df
# Out:
#                  Model  Train Accuracy  Test Accuracy  F1 Score
# 0  Logistic Regression        0.958242       0.947368  0.946397
# 1        Decision Tree        1.000000       0.912281  0.911273
# 2        Random Forest        1.000000       0.912281  0.909202
# 3             CatBoost        1.000000       0.912281  0.909972
# 4              XGBoost        1.000000       0.912281  0.909972
# 5                  SVC        0.973626       0.929825  0.928529
# 6                  KNN        0.962637       0.903509  0.901359

# %%
# Line Graph 
plt.figure(figsize=(22 ,4))
sns.lineplot(data=metrics_df, x="Model", y='Train Accuracy', marker='o', color='red', label='Train Accuracy')
sns.lineplot(data=metrics_df, x="Model", y='Test Accuracy', marker='o', color='green', label='Test Accuracy')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy of Different Models')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations :__
#
# - "Among all 7 models, the Logistic Regression model demonstrated superior performance in both training and testing, achieving a training accuracy of 95.82% and a testing accuracy of 94.73%, accompanied by a commendable F1-score of 94.63%."
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### ***Hyperparameter Tuning for Logistic Regression Model :***
# - _Using  ***"GridSearchCV"*** for Hyperparameter Tuning_

# %%
param_grid = {
            'C': [0.001, 0.01, 0.1, 1, 10, 100],  
            'penalty': ['l1', 'l2'],               
            'solver': ['liblinear', 'saga'],      
            'max_iter': [100, 200, 300],          
             }

#----------------------------------------------------------------------------------------------------
#Model
logr_model = LogisticRegression(multi_class='auto')
#----------------------------------------------------------------------------------------------------
#GridSearchCV
grid_search = GridSearchCV(estimator=logr_model , param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train)
#----------------------------------------------------------------------------------------------------
#Best parameters
best_parameters=grid_search.best_params_
print("Best hyperparameters:",best_parameters)
#----------------------------------------------------------------------------------------------------
#Best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_scaled)
#----------------------------------------------------------------------------------------------------
#Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Model accuracy:",accuracy)
#----------------------------------------------------------------------------------------------------
#Classification report
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
#----------------------------------------------------------------------------------------------------
#Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="Reds", fmt="d", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("Actual Labels")
plt.show()
# Out:
# Best hyperparameters: {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Model accuracy: 0.9473684210526315
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        72
#            1       1.00      0.86      0.92        42
#
#     accuracy                           0.95       114
#    macro avg       0.96      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %% [markdown]
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# __Observations :__
#
# 1. The Best HyperParameters of Logistic Regression are :
# - `C=0.1`
# - `max_iter=100`
# - `penalty="l2"`
# - `solver="linlinear"`
#
# 2. Accuracy=`94.73%`
#
#
# `"In the future, the model will be trained with a sufficient amount of balanced data to achieve better performance."`
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
